# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ==============================
# Lista dos 50 jogadores mais valiosos
# Valores em milhões de euros (€)
# ==============================

data = [
    ["Kylian Mbappé", 25, "Real Madrid", 180],
    ["Erling Haaland", 24, "Manchester City", 180],
    ["Jude Bellingham", 21, "Real Madrid", 180],
    ["Vinícius Júnior", 24, "Real Madrid", 170],
    ["Bukayo Saka", 23, "Arsenal", 150],
    ["Phil Foden", 24, "Manchester City", 150],
    ["Jamal Musiala", 21, "Bayern Munich", 140],
    ["Florian Wirtz", 21, "Bayer Leverkusen", 130],
    ["Rodrygo", 23, "Real Madrid", 120],
    ["Pedri", 21, "Barcelona", 120],
    ["Gavi", 20, "Barcelona", 110],
    ["Victor Osimhen", 25, "Napoli", 110],
    ["Declan Rice", 25, "Arsenal", 110],
    ["Martin Ødegaard", 25, "Arsenal", 110],
    ["Federico Valverde", 26, "Real Madrid", 110],
    ["Lautaro Martínez", 27, "Inter", 110],
    ["Harry Kane", 31, "Bayern Munich", 110],
    ["Khvicha Kvaratskhelia", 23, "Napoli", 100],
    ["Bernardo Silva", 30, "Manchester City", 100],
    ["Bruno Fernandes", 30, "Manchester United", 100],
    ["Rafael Leão", 25, "Milan", 100],
    ["Christopher Nkunku", 26, "Chelsea", 95],
    ["Joshua Kimmich", 29, "Bayern Munich", 95],
    ["Aurélien Tchouaméni", 24, "Real Madrid", 90],
    ["Eduardo Camavinga", 21, "Real Madrid", 90],
    ["Enzo Fernández", 23, "Chelsea", 90],
    ["Marcus Rashford", 27, "Manchester United", 90],
    ["Son Heung-min", 32, "Tottenham", 85],
    ["Alphonso Davies", 23, "Bayern Munich", 85],
    ["Achraf Hakimi", 26, "PSG", 80],
    ["Trent Alexander-Arnold", 26, "Liverpool", 80],
    ["Robert Lewandowski", 36, "Barcelona", 80],
    ["Neymar", 32, "Al Hilal", 80],
    ["Mohamed Salah", 32, "Liverpool", 80],
    ["Kevin De Bruyne", 33, "Manchester City", 80],
    ["Casemiro", 32, "Manchester United", 75],
    ["Bruno Guimarães", 26, "Newcastle", 75],
    ["Gabriel Martinelli", 23, "Arsenal", 75],
    ["Rúben Dias", 27, "Manchester City", 75],
    ["Marquinhos", 30, "PSG", 70],
    ["João Félix", 25, "Barcelona", 70],
    ["Frenkie de Jong", 27, "Barcelona", 70],
    ["Matthijs de Ligt", 25, "Bayern Munich", 70],
    ["Darwin Núñez", 25, "Liverpool", 70],
    ["Luis Díaz", 27, "Liverpool", 70],
    ["Mason Mount", 25, "Manchester United", 65],
    ["Jack Grealish", 29, "Manchester City", 65],
    ["Theo Hernández", 27, "Milan", 65],
    ["Nicolo Barella", 27, "Inter", 65],
    ["Sergej Milinković-Savić", 29, "Al Hilal", 60],
]

df = pd.DataFrame(data, columns=["Nome", "Idade", "Clube", "Valor (€ mi)"])

# ==============================
# AJUSTE RAPIDO
# ==============================

df.index = range(1, len(df) + 1)
df.index.name = "Jogadores"

# ==============================
# TABELA
# ==============================

print(df)

# ==============================
# Gráfico Top 10 mais valiosos
# ==============================

top10 = df.sort_values(by="Valor (€ mi)", ascending=False).head(10)

plt.figure(figsize=(12,6))
plt.bar(top10["Nome"], top10["Valor (€ mi)"])
plt.xticks(rotation=45, ha="right")
plt.title("Top 10 Jogadores Mais Valiosos do Mundo")
plt.ylabel("Valor (€ milhões)")
plt.tight_layout()
plt.show()
# Out:
#                               Nome  Idade              Clube  Valor (€ mi)
# Jogadores
# 1                    Kylian Mbappé     25        Real Madrid           180
# 2                   Erling Haaland     24    Manchester City           180
# 3                  Jude Bellingham     21        Real Madrid           180
# 4                  Vinícius Júnior     24        Real Madrid           170
# 5                      Bukayo Saka     23            Arsenal           150
# 6                       Phil Foden     24    Manchester City           150
# 7                    Jamal Musiala     21      Bayern Munich           140
# 8                    Florian Wirtz     21   Bayer Leverkusen           130
# 9                          Rodrygo     23        Real Madrid           120
# 10                           Pedri     21          Barcelona           120
# 11                            Gavi     20          Barcelona           110
# ...
